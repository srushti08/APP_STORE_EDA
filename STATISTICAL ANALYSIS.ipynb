# %%
import pandas as pd
import numpy as np

print(pd.__version__)
print(np.__version__)
# Out:
# 2.3.3
# 2.2.5

# %%
import sys
print(sys.executable)
# Out:
# F:\anaconda\envs\dev_env\python.exe

# %%
import pandas as pd
data=pd.read_csv("googleplaystore.csv")

# %%
data.shape
# Out:
# (10841, 13)

# %%
data.head(10)
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
# 5                         Paper flowers instructions  ART_AND_DESIGN     4.4
# 6            Smoke Effect Photo Maker - Smoke Editor  ART_AND_DESIGN     3.8
# 7                                   Infinite Painter  ART_AND_DESIGN     4.1
# 8                               Garden Coloring Book  ART_AND_DESIGN     4.4
# 9                      Kids Paint Free - Drawing Fun  ART_AND_DESIGN     4.7
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
# 5     167  5.6M      50,000+  Free     0       Everyone
# 6     178   19M      50,000+  Free     0       Everyone
# 7   36815   29M   1,000,000+  Free     0       Everyone
# 8   13791   33M   1,000,000+  Free     0       Everyone
# 9     121  3.1M      10,000+  Free     0       Everyone
#
#                       Genres        Last Updated         Current Ver  \
# 0               Art & Design     January 7, 2018               1.0.0
# 1  Art & Design;Pretend Play    January 15, 2018               2.0.0
# 2               Art & Design      August 1, 2018               1.2.4
# 3               Art & Design        June 8, 2018  Varies with device
# 4    Art & Design;Creativity       June 20, 2018                 1.1
# 5               Art & Design      March 26, 2017                 1.0
# 6               Art & Design      April 26, 2018                 1.1
# 7               Art & Design       June 14, 2018            6.1.61.1
# 8               Art & Design  September 20, 2017               2.9.2
# 9    Art & Design;Creativity        July 3, 2018                 2.8
#
#     Android Ver
# 0  4.0.3 and up
# 1  4.0.3 and up
# 2  4.0.3 and up
# 3    4.2 and up
# 4    4.4 and up
# 5    2.3 and up
# 6  4.0.3 and up
# 7    4.2 and up
# 8    3.0 and up
# 9  4.0.3 and up

# %%
data.tail()
# Out:
#                                                  App             Category  \
# 10836                               Sya9a Maroc - FR               FAMILY
# 10837               Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                         Parkinson Exercices FR              MEDICAL
# 10839                  The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840  iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        Rating Reviews                Size     Installs  Type Price  \
# 10836     4.5      38                 53M       5,000+  Free     0
# 10837     5.0       4                3.6M         100+  Free     0
# 10838     NaN       3                9.5M       1,000+  Free     0
# 10839     4.5     114  Varies with device       1,000+  Free     0
# 10840     4.5  398307                 19M  10,000,000+  Free     0
#
#       Content Rating             Genres      Last Updated         Current Ver  \
# 10836       Everyone          Education     July 25, 2017                1.48
# 10837       Everyone          Education      July 6, 2018                 1.0
# 10838       Everyone            Medical  January 20, 2017                 1.0
# 10839     Mature 17+  Books & Reference  January 19, 2015  Varies with device
# 10840       Everyone          Lifestyle     July 25, 2018  Varies with device
#
#               Android Ver
# 10836          4.1 and up
# 10837          4.1 and up
# 10838          2.2 and up
# 10839  Varies with device
# 10840  Varies with device

# %%
data.sample(10)
# Out:
#                                                     App             Category  \
# 5438                                          3D Tennis               SPORTS
# 1740                                Angry Birds Classic                 GAME
# 2924                                      Photo Editor-          PHOTOGRAPHY
# 3837         My Location: GPS Maps, Share & Save Places  MAPS_AND_NAVIGATION
# 5650                                                 au               FAMILY
# 5286                                      Book of AK-47            LIFESTYLE
# 9032                                    Piczle Lines DX               FAMILY
# 577                           Glam - Premium Dating App               DATING
# 9334                             EG Classroom Decimals™               FAMILY
# 5400  Resume Builder Free, 5 Minute CV Maker & Templ...             BUSINESS
#
#       Rating  Reviews                Size      Installs  Type  Price  \
# 5438     4.2  1008012                 13M   50,000,000+  Free      0
# 1740     4.4  5566805                 97M  100,000,000+  Free      0
# 2924     4.3    68071  Varies with device    5,000,000+  Free      0
# 3837     4.3    29768  Varies with device    5,000,000+  Free      0
# 5650     3.2     9126                5.8M    1,000,000+  Free      0
# 5286     3.8        6                3.4M          500+  Free      0
# 9032     4.6      281                 26M        5,000+  Free      0
# 577      4.3    23170                9.0M      500,000+  Free      0
# 9334     3.0        2                 18M           50+  Paid  $2.99
# 5400     4.4    72202                6.7M    1,000,000+  Free      0
#
#      Content Rating               Genres      Last Updated  \
# 5438       Everyone               Sports  December 5, 2017
# 1740       Everyone               Arcade      May 24, 2018
# 2924       Everyone          Photography       May 5, 2018
# 3837       Everyone    Maps & Navigation    August 4, 2018
# 5650       Everyone             Strategy      June 8, 2016
# 5286       Everyone            Lifestyle     March 1, 2016
# 9032       Everyone               Puzzle    April 15, 2018
# 577      Mature 17+               Dating     July 25, 2018
# 9334       Everyone  Education;Education     June 12, 2017
# 5400       Everyone             Business     June 25, 2018
#
#              Current Ver         Android Ver
# 5438               1.7.7          2.1 and up
# 1740               7.9.3          4.1 and up
# 2924  Varies with device  Varies with device
# 3837  Varies with device  Varies with device
# 5650               1.0.9          4.0 and up
# 5286               1.0.2        4.0.3 and up
# 9032               1.4.6          4.0 and up
# 577              1.5.4.0          4.1 and up
# 9334               2.2.2          2.2 and up
# 5400                 6.0        4.0.3 and up

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  object
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 1.1+ MB

# %%
data.describe(include='all').T
# Out:
#                  count unique                 top   freq      mean       std  \
# App              10841   9660              ROBLOX      9       NaN       NaN
# Category         10841     34              FAMILY   1972       NaN       NaN
# Rating          9367.0    NaN                 NaN    NaN  4.193338  0.537431
# Reviews          10841   6002                   0    596       NaN       NaN
# Size             10841    462  Varies with device   1695       NaN       NaN
# Installs         10841     22          1,000,000+   1579       NaN       NaN
# Type             10840      3                Free  10039       NaN       NaN
# Price            10841     93                   0  10040       NaN       NaN
# Content Rating   10840      6            Everyone   8714       NaN       NaN
# Genres           10841    120               Tools    842       NaN       NaN
# Last Updated     10841   1378      August 3, 2018    326       NaN       NaN
# Current Ver      10833   2832  Varies with device   1459       NaN       NaN
# Android Ver      10838     33          4.1 and up   2451       NaN       NaN
#
#                 min  25%  50%  75%   max
# App             NaN  NaN  NaN  NaN   NaN
# Category        NaN  NaN  NaN  NaN   NaN
# Rating          1.0  4.0  4.3  4.5  19.0
# Reviews         NaN  NaN  NaN  NaN   NaN
# Size            NaN  NaN  NaN  NaN   NaN
# Installs        NaN  NaN  NaN  NaN   NaN
# Type            NaN  NaN  NaN  NaN   NaN
# Price           NaN  NaN  NaN  NaN   NaN
# Content Rating  NaN  NaN  NaN  NaN   NaN
# Genres          NaN  NaN  NaN  NaN   NaN
# Last Updated    NaN  NaN  NaN  NaN   NaN
# Current Ver     NaN  NaN  NaN  NaN   NaN
# Android Ver     NaN  NaN  NaN  NaN   NaN

# %%
data[data.duplicated()].T
# Out:
#                                        229                 236    \
# App             Quick PDF Scanner + OCR FREE                 Box
# Category                            BUSINESS            BUSINESS
# Rating                                   4.2                 4.2
# Reviews                                80805              159872
# Size                      Varies with device  Varies with device
# Installs                          5,000,000+         10,000,000+
# Type                                    Free                Free
# Price                                      0                   0
# Content Rating                      Everyone            Everyone
# Genres                              Business            Business
# Last Updated               February 26, 2018       July 31, 2018
# Current Ver               Varies with device  Varies with device
# Android Ver                     4.0.3 and up  Varies with device
#
#                              239                  256    \
# App             Google My Business  ZOOM Cloud Meetings
# Category                  BUSINESS             BUSINESS
# Rating                         4.4                  4.4
# Reviews                      70991                31614
# Size            Varies with device                  37M
# Installs                5,000,000+          10,000,000+
# Type                          Free                 Free
# Price                            0                    0
# Content Rating            Everyone             Everyone
# Genres                    Business             Business
# Last Updated         July 24, 2018        July 20, 2018
# Current Ver       2.19.0.204537701       4.1.28165.0716
# Android Ver             4.4 and up           4.0 and up
#
#                                     261                 265            266    \
# App             join.me - Simple Meetings                 Box       Zenefits
# Category                         BUSINESS            BUSINESS       BUSINESS
# Rating                                4.0                 4.2            4.2
# Reviews                              6989              159872            296
# Size                   Varies with device  Varies with device            14M
# Installs                       1,000,000+         10,000,000+        50,000+
# Type                                 Free                Free           Free
# Price                                   0                   0              0
# Content Rating                   Everyone            Everyone       Everyone
# Genres                           Business            Business       Business
# Last Updated                July 16, 2018       July 31, 2018  June 15, 2018
# Current Ver                     4.3.0.508  Varies with device          3.2.1
# Android Ver                    4.4 and up  Varies with device     4.1 and up
#
#                         267                 268                 269    ...  \
# App                Google Ads  Google My Business               Slack  ...
# Category             BUSINESS            BUSINESS            BUSINESS  ...
# Rating                    4.3                 4.4                 4.4  ...
# Reviews                 29313               70991               51507  ...
# Size                      20M  Varies with device  Varies with device  ...
# Installs           5,000,000+          5,000,000+          5,000,000+  ...
# Type                     Free                Free                Free  ...
# Price                       0                   0                   0  ...
# Content Rating       Everyone            Everyone            Everyone  ...
# Genres               Business            Business            Business  ...
# Last Updated    July 30, 2018       July 24, 2018      August 2, 2018  ...
# Current Ver            1.12.0    2.19.0.204537701  Varies with device  ...
# Android Ver      4.0.3 and up          4.4 and up  Varies with device  ...
#
#                                8632   \
# App             Notepad & To do list
# Category                PRODUCTIVITY
# Rating                           4.3
# Reviews                       226295
# Size                            4.2M
# Installs                 10,000,000+
# Type                            Free
# Price                              0
# Content Rating              Everyone
# Genres                  Productivity
# Last Updated            June 6, 2018
# Current Ver                   4.3.19
# Android Ver             2.3.3 and up
#
#                                                           8635   \
# App             Polaris Office - Word, Docs, Sheets, Slide, PDF
# Category                                           PRODUCTIVITY
# Rating                                                      4.3
# Reviews                                                  549900
# Size                                                        60M
# Installs                                            10,000,000+
# Type                                                       Free
# Price                                                         0
# Content Rating                                         Everyone
# Genres                                             Productivity
# Last Updated                                      July 18, 2018
# Current Ver                                              7.3.30
# Android Ver                                          4.1 and up
#
#                              8636                         8639   \
# App                    Google Keep  Do It Later: Tasks & To-Dos
# Category              PRODUCTIVITY                 PRODUCTIVITY
# Rating                         4.4                          4.5
# Reviews                     691474                       123412
# Size            Varies with device           Varies with device
# Installs              100,000,000+                  50,000,000+
# Type                          Free                         Free
# Price                            0                            0
# Content Rating            Everyone                     Everyone
# Genres                Productivity                 Productivity
# Last Updated        August 6, 2018               April 13, 2018
# Current Ver     Varies with device           Varies with device
# Android Ver     Varies with device           Varies with device
#
#                                  8642                            8643   \
# App             To-Do Calendar Planner  Wunderlist: To-Do List & Tasks
# Category                  PRODUCTIVITY                    PRODUCTIVITY
# Rating                             4.2                             4.6
# Reviews                          30291                          404610
# Size                Varies with device              Varies with device
# Installs                    1,000,000+                     10,000,000+
# Type                              Free                            Free
# Price                                0                               0
# Content Rating                Everyone                        Everyone
# Genres                    Productivity                    Productivity
# Last Updated              May 29, 2018                   April 6, 2018
# Current Ver         Varies with device              Varies with device
# Android Ver         Varies with device              Varies with device
#
#                                                           8654   \
# App             TickTick: To Do List with Reminder, Day Planner
# Category                                           PRODUCTIVITY
# Rating                                                      4.6
# Reviews                                                   25370
# Size                                         Varies with device
# Installs                                             1,000,000+
# Type                                                       Free
# Price                                                         0
# Content Rating                                         Everyone
# Genres                                             Productivity
# Last Updated                                     August 6, 2018
# Current Ver                                  Varies with device
# Android Ver                                  Varies with device
#
#                                   8658   \
# App             ColorNote Notepad Notes
# Category                   PRODUCTIVITY
# Rating                              4.6
# Reviews                         2401017
# Size                 Varies with device
# Installs                   100,000,000+
# Type                               Free
# Price                                 0
# Content Rating                 Everyone
# Genres                     Productivity
# Last Updated              June 27, 2018
# Current Ver          Varies with device
# Android Ver          Varies with device
#
#                                                     10049          10768
# App             Airway Ex - Intubate. Anesthetize. Train.           AAFP
# Category                                          MEDICAL        MEDICAL
# Rating                                                4.3            3.8
# Reviews                                               123             63
# Size                                                  86M            24M
# Installs                                          10,000+        10,000+
# Type                                                 Free           Free
# Price                                                   0              0
# Content Rating                                   Everyone       Everyone
# Genres                                            Medical        Medical
# Last Updated                                 June 1, 2018  June 22, 2018
# Current Ver                                        0.6.88          2.3.1
# Android Ver                                    5.0 and up     5.0 and up
#
# [13 rows x 483 columns]

# %%
data['Reviews'].head(20)
# Out:
# 0        159
# 1        967
# 2      87510
# 3     215644
# 4        967
# 5        167
# 6        178
# 7      36815
# 8      13791
# 9        121
# 10     13880
# 11      8788
# 12     44829
# 13      4326
# 14      1518
# 15        55
# 16      3632
# 17        27
# 18    194216
# 19    224399
# Name: Reviews, dtype: object

# %%
data['Reviews'].shape
# Out:
# (10841,)

# %%
data['Reviews'].dtype
# Out:
# dtype('O')

# %%
data.Reviews.str

# %%
data[data.Reviews.str.isnumeric()].head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# 1  Art & Design;Pretend Play  January 15, 2018               2.0.0
# 2               Art & Design    August 1, 2018               1.2.4
# 3               Art & Design      June 8, 2018  Varies with device
# 4    Art & Design;Creativity     June 20, 2018                 1.1
#
#     Android Ver
# 0  4.0.3 and up
# 1  4.0.3 and up
# 2  4.0.3 and up
# 3    4.2 and up
# 4    4.4 and up

# %%
data[~data.Reviews.str.isnumeric()]
# Out:
#                                            App Category  Rating Reviews  \
# 10472  Life Made WI-Fi Touchscreen Photo Frame      1.9    19.0    3.0M
#
#          Size Installs Type     Price Content Rating             Genres  \
# 10472  1,000+     Free    0  Everyone            NaN  February 11, 2018
#
#       Last Updated Current Ver Android Ver
# 10472       1.0.19  4.0 and up         NaN

# %%
data_copy=data.copy()

# %%
#we are deleting the row 10472 from data cz its not a numeric 
data_copy=data_copy.drop(data_copy.index[10472])

# %%
data_copy.index[10472]
# Out:
# np.int64(10473)

# %%
data_copy.shape
# Out:
# (10840, 13)

# %%
data.shape
# Out:
# (10841, 13)

# %%
data_copy['Reviews'].dtype
# Out:
# dtype('O')

# %%
data_copy['Reviews']=data_copy['Reviews'].astype('int')

# %%
#we changed the datatype of review in int64
data_copy['Reviews'].dtype
# Out:
# dtype('int64')

# %%
data_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10840 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10840 non-null  object
#  1   Category        10840 non-null  object
#  2   Rating          9366 non-null   float64
#  3   Reviews         10840 non-null  int64
#  4   Size            10840 non-null  object
#  5   Installs        10840 non-null  object
#  6   Type            10839 non-null  object
#  7   Price           10840 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10840 non-null  object
#  10  Last Updated    10840 non-null  object
#  11  Current Ver     10832 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(1), int64(1), object(11)
# memory usage: 1.2+ MB

# %%
#size indicates size of tht app
data_copy["Size"]
# Out:
# 0                       19M
# 1                       14M
# 2                      8.7M
# 3                       25M
# 4                      2.8M
#                 ...
# 10836                   53M
# 10837                  3.6M
# 10838                  9.5M
# 10839    Varies with device
# 10840                   19M
# Name: Size, Length: 10840, dtype: object

# %%
data_copy["Size"].unique()
# Out:
# array(['19M', '14M', '8.7M', '25M', '2.8M', '5.6M', '29M', '33M', '3.1M',
#        '28M', '12M', '20M', '21M', '37M', '2.7M', '5.5M', '17M', '39M',
#        '31M', '4.2M', '7.0M', '23M', '6.0M', '6.1M', '4.6M', '9.2M',
#        '5.2M', '11M', '24M', 'Varies with device', '9.4M', '15M', '10M',
#        '1.2M', '26M', '8.0M', '7.9M', '56M', '57M', '35M', '54M', '201k',
#        '3.6M', '5.7M', '8.6M', '2.4M', '27M', '2.5M', '16M', '3.4M',
#        '8.9M', '3.9M', '2.9M', '38M', '32M', '5.4M', '18M', '1.1M',
#        '2.2M', '4.5M', '9.8M', '52M', '9.0M', '6.7M', '30M', '2.6M',
#        '7.1M', '3.7M', '22M', '7.4M', '6.4M', '3.2M', '8.2M', '9.9M',
#        '4.9M', '9.5M', '5.0M', '5.9M', '13M', '73M', '6.8M', '3.5M',
#        '4.0M', '2.3M', '7.2M', '2.1M', '42M', '7.3M', '9.1M', '55M',
#        '23k', '6.5M', '1.5M', '7.5M', '51M', '41M', '48M', '8.5M', '46M',
#        '8.3M', '4.3M', '4.7M', '3.3M', '40M', '7.8M', '8.8M', '6.6M',
#        '5.1M', '61M', '66M', '79k', '8.4M', '118k', '44M', '695k', '1.6M',
#        '6.2M', '18k', '53M', '1.4M', '3.0M', '5.8M', '3.8M', '9.6M',
#        '45M', '63M', '49M', '77M', '4.4M', '4.8M', '70M', '6.9M', '9.3M',
#        '10.0M', '8.1M', '36M', '84M', '97M', '2.0M', '1.9M', '1.8M',
#        '5.3M', '47M', '556k', '526k', '76M', '7.6M', '59M', '9.7M', '78M',
#        '72M', '43M', '7.7M', '6.3M', '334k', '34M', '93M', '65M', '79M',
#        '100M', '58M', '50M', '68M', '64M', '67M', '60M', '94M', '232k',
#        '99M', '624k', '95M', '8.5k', '41k', '292k', '11k', '80M', '1.7M',
#        '74M', '62M', '69M', '75M', '98M', '85M', '82M', '96M', '87M',
#        '71M', '86M', '91M', '81M', '92M', '83M', '88M', '704k', '862k',
#        '899k', '378k', '266k', '375k', '1.3M', '975k', '980k', '4.1M',
#        '89M', '696k', '544k', '525k', '920k', '779k', '853k', '720k',
#        '713k', '772k', '318k', '58k', '241k', '196k', '857k', '51k',
#        '953k', '865k', '251k', '930k', '540k', '313k', '746k', '203k',
#        '26k', '314k', '239k', '371k', '220k', '730k', '756k', '91k',
#        '293k', '17k', '74k', '14k', '317k', '78k', '924k', '902k', '818k',
#        '81k', '939k', '169k', '45k', '475k', '965k', '90M', '545k', '61k',
#        '283k', '655k', '714k', '93k', '872k', '121k', '322k', '1.0M',
#        '976k', '172k', '238k', '549k', '206k', '954k', '444k', '717k',
#        '210k', '609k', '308k', '705k', '306k', '904k', '473k', '175k',
#        '350k', '383k', '454k', '421k', '70k', '812k', '442k', '842k',
#        '417k', '412k', '459k', '478k', '335k', '782k', '721k', '430k',
#        '429k', '192k', '200k', '460k', '728k', '496k', '816k', '414k',
#        '506k', '887k', '613k', '243k', '569k', '778k', '683k', '592k',
#        '319k', '186k', '840k', '647k', '191k', '373k', '437k', '598k',
#        '716k', '585k', '982k', '222k', '219k', '55k', '948k', '323k',
#        '691k', '511k', '951k', '963k', '25k', '554k', '351k', '27k',
#        '82k', '208k', '913k', '514k', '551k', '29k', '103k', '898k',
#        '743k', '116k', '153k', '209k', '353k', '499k', '173k', '597k',
#        '809k', '122k', '411k', '400k', '801k', '787k', '237k', '50k',
#        '643k', '986k', '97k', '516k', '837k', '780k', '961k', '269k',
#        '20k', '498k', '600k', '749k', '642k', '881k', '72k', '656k',
#        '601k', '221k', '228k', '108k', '940k', '176k', '33k', '663k',
#        '34k', '942k', '259k', '164k', '458k', '245k', '629k', '28k',
#        '288k', '775k', '785k', '636k', '916k', '994k', '309k', '485k',
#        '914k', '903k', '608k', '500k', '54k', '562k', '847k', '957k',
#        '688k', '811k', '270k', '48k', '329k', '523k', '921k', '874k',
#        '981k', '784k', '280k', '24k', '518k', '754k', '892k', '154k',
#        '860k', '364k', '387k', '626k', '161k', '879k', '39k', '970k',
#        '170k', '141k', '160k', '144k', '143k', '190k', '376k', '193k',
#        '246k', '73k', '658k', '992k', '253k', '420k', '404k', '470k',
#        '226k', '240k', '89k', '234k', '257k', '861k', '467k', '157k',
#        '44k', '676k', '67k', '552k', '885k', '1020k', '582k', '619k'],
#       dtype=object)

# %%
data_copy["Size"].dtype
# Out:
# dtype('O')

# %%
data_copy["Size"].shape
# Out:
# (10840,)

# %%
data_copy.duplicated(subset=["Size"]).sum()
# Out:
# np.int64(10379)

# %%
data_copy["Size"]=data_copy["Size"].str.replace("M","000")

# %%
data_copy["Size"].sample(10)
# Out:
# 7646                  30000
# 6919                  26000
# 8883                   994k
# 529      Varies with device
# 223                  1.5000
# 2602                 4.1000
# 10198                5.8000
# 140                  4.9000
# 2892                 5.7000
# 228      Varies with device
# Name: Size, dtype: object

# %%
data_copy["Size"]=data_copy["Size"].str.replace("k","")

# %%
data_copy["Size"].unique()
# Out:
# array(['19000', '14000', '8.7000', '25000', '2.8000', '5.6000', '29000',
#        '33000', '3.1000', '28000', '12000', '20000', '21000', '37000',
#        '2.7000', '5.5000', '17000', '39000', '31000', '4.2000', '7.0000',
#        '23000', '6.0000', '6.1000', '4.6000', '9.2000', '5.2000', '11000',
#        '24000', 'Varies with device', '9.4000', '15000', '10000',
#        '1.2000', '26000', '8.0000', '7.9000', '56000', '57000', '35000',
#        '54000', '201', '3.6000', '5.7000', '8.6000', '2.4000', '27000',
#        '2.5000', '16000', '3.4000', '8.9000', '3.9000', '2.9000', '38000',
#        '32000', '5.4000', '18000', '1.1000', '2.2000', '4.5000', '9.8000',
#        '52000', '9.0000', '6.7000', '30000', '2.6000', '7.1000', '3.7000',
#        '22000', '7.4000', '6.4000', '3.2000', '8.2000', '9.9000',
#        '4.9000', '9.5000', '5.0000', '5.9000', '13000', '73000', '6.8000',
#        '3.5000', '4.0000', '2.3000', '7.2000', '2.1000', '42000',
#        '7.3000', '9.1000', '55000', '23', '6.5000', '1.5000', '7.5000',
#        '51000', '41000', '48000', '8.5000', '46000', '8.3000', '4.3000',
#        '4.7000', '3.3000', '40000', '7.8000', '8.8000', '6.6000',
#        '5.1000', '61000', '66000', '79', '8.4000', '118', '44000', '695',
#        '1.6000', '6.2000', '18', '53000', '1.4000', '3.0000', '5.8000',
#        '3.8000', '9.6000', '45000', '63000', '49000', '77000', '4.4000',
#        '4.8000', '70000', '6.9000', '9.3000', '10.0000', '8.1000',
#        '36000', '84000', '97000', '2.0000', '1.9000', '1.8000', '5.3000',
#        '47000', '556', '526', '76000', '7.6000', '59000', '9.7000',
#        '78000', '72000', '43000', '7.7000', '6.3000', '334', '34000',
#        '93000', '65000', '79000', '100000', '58000', '50000', '68000',
#        '64000', '67000', '60000', '94000', '232', '99000', '624', '95000',
#        '8.5', '41', '292', '11', '80000', '1.7000', '74000', '62000',
#        '69000', '75000', '98000', '85000', '82000', '96000', '87000',
#        '71000', '86000', '91000', '81000', '92000', '83000', '88000',
#        '704', '862', '899', '378', '266', '375', '1.3000', '975', '980',
#        '4.1000', '89000', '696', '544', '525', '920', '779', '853', '720',
#        '713', '772', '318', '58', '241', '196', '857', '51', '953', '865',
#        '251', '930', '540', '313', '746', '203', '26', '314', '239',
#        '371', '220', '730', '756', '91', '293', '17', '74', '14', '317',
#        '78', '924', '902', '818', '81', '939', '169', '45', '475', '965',
#        '90000', '545', '61', '283', '655', '714', '93', '872', '121',
#        '322', '1.0000', '976', '172', '238', '549', '206', '954', '444',
#        '717', '210', '609', '308', '705', '306', '904', '473', '175',
#        '350', '383', '454', '421', '70', '812', '442', '842', '417',
#        '412', '459', '478', '335', '782', '721', '430', '429', '192',
#        '200', '460', '728', '496', '816', '414', '506', '887', '613',
#        '243', '569', '778', '683', '592', '319', '186', '840', '647',
#        '191', '373', '437', '598', '716', '585', '982', '222', '219',
#        '55', '948', '323', '691', '511', '951', '963', '25', '554', '351',
#        '27', '82', '208', '913', '514', '551', '29', '103', '898', '743',
#        '116', '153', '209', '353', '499', '173', '597', '809', '122',
#        '411', '400', '801', '787', '237', '50', '643', '986', '97', '516',
#        '837', '780', '961', '269', '20', '498', '600', '749', '642',
#        '881', '72', '656', '601', '221', '228', '108', '940', '176', '33',
#        '663', '34', '942', '259', '164', '458', '245', '629', '28', '288',
#        '775', '785', '636', '916', '994', '309', '485', '914', '903',
#        '608', '500', '54', '562', '847', '957', '688', '811', '270', '48',
#        '329', '523', '921', '874', '981', '784', '280', '24', '518',
#        '754', '892', '154', '860', '364', '387', '626', '161', '879',
#        '39', '970', '170', '141', '160', '144', '143', '190', '376',
#        '193', '246', '73', '658', '992', '253', '420', '404', '470',
#        '226', '240', '89', '234', '257', '861', '467', '157', '44', '676',
#        '67', '552', '885', '1020', '582', '619'], dtype=object)

# %%
#str(np.nan)
#NumPy's nan: Standing for "Not a Number," np.nan is a special floating-point value used to represent missing or undefined data.
#Since your "Size" column is currently a column of strings (Object), you are replacing one string ("Varies with device") with another string ("nan").
import numpy as np
data_copy["Size"]=data_copy["Size"].str.replace('Varies with device',str(np.nan))

# %%
#unique value doesnt count nan/null values 
data_copy["Size"].unique()
# Out:
# array(['19000', '14000', '8.7000', '25000', '2.8000', '5.6000', '29000',
#        '33000', '3.1000', '28000', '12000', '20000', '21000', '37000',
#        '2.7000', '5.5000', '17000', '39000', '31000', '4.2000', '7.0000',
#        '23000', '6.0000', '6.1000', '4.6000', '9.2000', '5.2000', '11000',
#        '24000', 'nan', '9.4000', '15000', '10000', '1.2000', '26000',
#        '8.0000', '7.9000', '56000', '57000', '35000', '54000', '201',
#        '3.6000', '5.7000', '8.6000', '2.4000', '27000', '2.5000', '16000',
#        '3.4000', '8.9000', '3.9000', '2.9000', '38000', '32000', '5.4000',
#        '18000', '1.1000', '2.2000', '4.5000', '9.8000', '52000', '9.0000',
#        '6.7000', '30000', '2.6000', '7.1000', '3.7000', '22000', '7.4000',
#        '6.4000', '3.2000', '8.2000', '9.9000', '4.9000', '9.5000',
#        '5.0000', '5.9000', '13000', '73000', '6.8000', '3.5000', '4.0000',
#        '2.3000', '7.2000', '2.1000', '42000', '7.3000', '9.1000', '55000',
#        '23', '6.5000', '1.5000', '7.5000', '51000', '41000', '48000',
#        '8.5000', '46000', '8.3000', '4.3000', '4.7000', '3.3000', '40000',
#        '7.8000', '8.8000', '6.6000', '5.1000', '61000', '66000', '79',
#        '8.4000', '118', '44000', '695', '1.6000', '6.2000', '18', '53000',
#        '1.4000', '3.0000', '5.8000', '3.8000', '9.6000', '45000', '63000',
#        '49000', '77000', '4.4000', '4.8000', '70000', '6.9000', '9.3000',
#        '10.0000', '8.1000', '36000', '84000', '97000', '2.0000', '1.9000',
#        '1.8000', '5.3000', '47000', '556', '526', '76000', '7.6000',
#        '59000', '9.7000', '78000', '72000', '43000', '7.7000', '6.3000',
#        '334', '34000', '93000', '65000', '79000', '100000', '58000',
#        '50000', '68000', '64000', '67000', '60000', '94000', '232',
#        '99000', '624', '95000', '8.5', '41', '292', '11', '80000',
#        '1.7000', '74000', '62000', '69000', '75000', '98000', '85000',
#        '82000', '96000', '87000', '71000', '86000', '91000', '81000',
#        '92000', '83000', '88000', '704', '862', '899', '378', '266',
#        '375', '1.3000', '975', '980', '4.1000', '89000', '696', '544',
#        '525', '920', '779', '853', '720', '713', '772', '318', '58',
#        '241', '196', '857', '51', '953', '865', '251', '930', '540',
#        '313', '746', '203', '26', '314', '239', '371', '220', '730',
#        '756', '91', '293', '17', '74', '14', '317', '78', '924', '902',
#        '818', '81', '939', '169', '45', '475', '965', '90000', '545',
#        '61', '283', '655', '714', '93', '872', '121', '322', '1.0000',
#        '976', '172', '238', '549', '206', '954', '444', '717', '210',
#        '609', '308', '705', '306', '904', '473', '175', '350', '383',
#        '454', '421', '70', '812', '442', '842', '417', '412', '459',
#        '478', '335', '782', '721', '430', '429', '192', '200', '460',
#        '728', '496', '816', '414', '506', '887', '613', '243', '569',
#        '778', '683', '592', '319', '186', '840', '647', '191', '373',
#        '437', '598', '716', '585', '982', '222', '219', '55', '948',
#        '323', '691', '511', '951', '963', '25', '554', '351', '27', '82',
#        '208', '913', '514', '551', '29', '103', '898', '743', '116',
#        '153', '209', '353', '499', '173', '597', '809', '122', '411',
#        '400', '801', '787', '237', '50', '643', '986', '97', '516', '837',
#        '780', '961', '269', '20', '498', '600', '749', '642', '881', '72',
#        '656', '601', '221', '228', '108', '940', '176', '33', '663', '34',
#        '942', '259', '164', '458', '245', '629', '28', '288', '775',
#        '785', '636', '916', '994', '309', '485', '914', '903', '608',
#        '500', '54', '562', '847', '957', '688', '811', '270', '48', '329',
#        '523', '921', '874', '981', '784', '280', '24', '518', '754',
#        '892', '154', '860', '364', '387', '626', '161', '879', '39',
#        '970', '170', '141', '160', '144', '143', '190', '376', '193',
#        '246', '73', '658', '992', '253', '420', '404', '470', '226',
#        '240', '89', '234', '257', '861', '467', '157', '44', '676', '67',
#        '552', '885', '1020', '582', '619'], dtype=object)

# %%
data_copy["Size"].dtype
# Out:
# dtype('O')

# %%
data_copy["Size"]=data_copy["Size"].astype("float")

# %%
data_copy["Size"].dtype
# Out:
# dtype('float64')

# %%
data_copy["Size"].head(10)
# Out:
# 0    19000.0
# 1    14000.0
# 2        8.7
# 3    25000.0
# 4        2.8
# 5        5.6
# 6    19000.0
# 7    29000.0
# 8    33000.0
# 9        3.1
# Name: Size, dtype: float64

# %%
data["Size"][0]
# Out:
# '19M'

# %%
#basically we converted 19M = 19000= 19*1000 and 8.7M= 8.7000=8.7*1000

# %%
data_copy["Size"][2]*1000
# Out:
# np.float64(8700.0)

# %%
for i in data_copy["Size"]:
    if i<10:
        data_copy["Size"]=data_copy["Size"].replace(i,i*1000)

# %%
data_copy["Size"].head(50)
# Out:
# 0     19000.0
# 1     14000.0
# 2      8700.0
# 3     25000.0
# 4      2800.0
# 5      5600.0
# 6     19000.0
# 7     29000.0
# 8     33000.0
# 9      3100.0
# 10    28000.0
# 11    12000.0
# 12    20000.0
# 13    21000.0
# 14    37000.0
# 15     2700.0
# 16     5500.0
# 17    17000.0
# 18    39000.0
# 19    31000.0
# 20    14000.0
# 21    12000.0
# 22     4200.0
# 23     7000.0
# 24    23000.0
# 25     6000.0
# 26    25000.0
# 27     6100.0
# 28     4600.0
# 29     4200.0
# 30     9200.0
# 31     5200.0
# 32    11000.0
# 33    11000.0
# 34     4200.0
# 35     9200.0
# 36    24000.0
# 37        NaN
# 38    11000.0
# 39     9400.0
# 40    15000.0
# 41    10000.0
# 42        NaN
# 43     1200.0
# 44    12000.0
# 45    24000.0
# 46    26000.0
# 47     8000.0
# 48     7900.0
# 49    25000.0
# Name: Size, dtype: float64

# %%
data_copy["Size"].dtype
# Out:
# dtype('float64')

# %%
data["Size"].unique()
# Out:
# array(['19M', '14M', '8.7M', '25M', '2.8M', '5.6M', '29M', '33M', '3.1M',
#        '28M', '12M', '20M', '21M', '37M', '2.7M', '5.5M', '17M', '39M',
#        '31M', '4.2M', '7.0M', '23M', '6.0M', '6.1M', '4.6M', '9.2M',
#        '5.2M', '11M', '24M', 'Varies with device', '9.4M', '15M', '10M',
#        '1.2M', '26M', '8.0M', '7.9M', '56M', '57M', '35M', '54M', '201k',
#        '3.6M', '5.7M', '8.6M', '2.4M', '27M', '2.5M', '16M', '3.4M',
#        '8.9M', '3.9M', '2.9M', '38M', '32M', '5.4M', '18M', '1.1M',
#        '2.2M', '4.5M', '9.8M', '52M', '9.0M', '6.7M', '30M', '2.6M',
#        '7.1M', '3.7M', '22M', '7.4M', '6.4M', '3.2M', '8.2M', '9.9M',
#        '4.9M', '9.5M', '5.0M', '5.9M', '13M', '73M', '6.8M', '3.5M',
#        '4.0M', '2.3M', '7.2M', '2.1M', '42M', '7.3M', '9.1M', '55M',
#        '23k', '6.5M', '1.5M', '7.5M', '51M', '41M', '48M', '8.5M', '46M',
#        '8.3M', '4.3M', '4.7M', '3.3M', '40M', '7.8M', '8.8M', '6.6M',
#        '5.1M', '61M', '66M', '79k', '8.4M', '118k', '44M', '695k', '1.6M',
#        '6.2M', '18k', '53M', '1.4M', '3.0M', '5.8M', '3.8M', '9.6M',
#        '45M', '63M', '49M', '77M', '4.4M', '4.8M', '70M', '6.9M', '9.3M',
#        '10.0M', '8.1M', '36M', '84M', '97M', '2.0M', '1.9M', '1.8M',
#        '5.3M', '47M', '556k', '526k', '76M', '7.6M', '59M', '9.7M', '78M',
#        '72M', '43M', '7.7M', '6.3M', '334k', '34M', '93M', '65M', '79M',
#        '100M', '58M', '50M', '68M', '64M', '67M', '60M', '94M', '232k',
#        '99M', '624k', '95M', '8.5k', '41k', '292k', '11k', '80M', '1.7M',
#        '74M', '62M', '69M', '75M', '98M', '85M', '82M', '96M', '87M',
#        '71M', '86M', '91M', '81M', '92M', '83M', '88M', '704k', '862k',
#        '899k', '378k', '266k', '375k', '1.3M', '975k', '980k', '4.1M',
#        '89M', '696k', '544k', '525k', '920k', '779k', '853k', '720k',
#        '713k', '772k', '318k', '58k', '241k', '196k', '857k', '51k',
#        '953k', '865k', '251k', '930k', '540k', '313k', '746k', '203k',
#        '26k', '314k', '239k', '371k', '220k', '730k', '756k', '91k',
#        '293k', '17k', '74k', '14k', '317k', '78k', '924k', '902k', '818k',
#        '81k', '939k', '169k', '45k', '475k', '965k', '90M', '545k', '61k',
#        '283k', '655k', '714k', '93k', '872k', '121k', '322k', '1.0M',
#        '976k', '172k', '238k', '549k', '206k', '954k', '444k', '717k',
#        '210k', '609k', '308k', '705k', '306k', '904k', '473k', '175k',
#        '350k', '383k', '454k', '421k', '70k', '812k', '442k', '842k',
#        '417k', '412k', '459k', '478k', '335k', '782k', '721k', '430k',
#        '429k', '192k', '200k', '460k', '728k', '496k', '816k', '414k',
#        '506k', '887k', '613k', '243k', '569k', '778k', '683k', '592k',
#        '319k', '186k', '840k', '647k', '191k', '373k', '437k', '598k',
#        '716k', '585k', '982k', '222k', '219k', '55k', '948k', '323k',
#        '691k', '511k', '951k', '963k', '25k', '554k', '351k', '27k',
#        '82k', '208k', '913k', '514k', '551k', '29k', '103k', '898k',
#        '743k', '116k', '153k', '209k', '353k', '499k', '173k', '597k',
#        '809k', '122k', '411k', '400k', '801k', '787k', '237k', '50k',
#        '643k', '986k', '97k', '516k', '837k', '780k', '961k', '269k',
#        '20k', '498k', '600k', '749k', '642k', '881k', '72k', '656k',
#        '601k', '221k', '228k', '108k', '940k', '176k', '33k', '663k',
#        '34k', '942k', '259k', '164k', '458k', '245k', '629k', '28k',
#        '288k', '775k', '785k', '636k', '916k', '994k', '309k', '485k',
#        '914k', '903k', '608k', '500k', '54k', '562k', '847k', '957k',
#        '688k', '811k', '270k', '48k', '329k', '523k', '921k', '874k',
#        '981k', '784k', '280k', '24k', '518k', '754k', '892k', '154k',
#        '860k', '364k', '387k', '626k', '161k', '879k', '39k', '970k',
#        '170k', '141k', '160k', '144k', '143k', '190k', '376k', '193k',
#        '246k', '73k', '658k', '992k', '253k', '420k', '404k', '1,000+',
#        '470k', '226k', '240k', '89k', '234k', '257k', '861k', '467k',
#        '157k', '44k', '676k', '67k', '552k', '885k', '1020k', '582k',
#        '619k'], dtype=object)

# %%
data.head(3)
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
#
#   Reviews  Size    Installs  Type Price Content Rating  \
# 0     159   19M     10,000+  Free     0       Everyone
# 1     967   14M    500,000+  Free     0       Everyone
# 2   87510  8.7M  5,000,000+  Free     0       Everyone
#
#                       Genres      Last Updated Current Ver   Android Ver
# 0               Art & Design   January 7, 2018       1.0.0  4.0.3 and up
# 1  Art & Design;Pretend Play  January 15, 2018       2.0.0  4.0.3 and up
# 2               Art & Design    August 1, 2018       1.2.4  4.0.3 and up

# %%
data_copy.head(3)
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
#
#    Reviews     Size    Installs  Type Price Content Rating  \
# 0      159  19000.0     10,000+  Free     0       Everyone
# 1      967  14000.0    500,000+  Free     0       Everyone
# 2    87510   8700.0  5,000,000+  Free     0       Everyone
#
#                       Genres      Last Updated Current Ver   Android Ver
# 0               Art & Design   January 7, 2018       1.0.0  4.0.3 and up
# 1  Art & Design;Pretend Play  January 15, 2018       2.0.0  4.0.3 and up
# 2               Art & Design    August 1, 2018       1.2.4  4.0.3 and up

# %%
data_copy.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')

# %%
data_copy["Installs"]
# Out:
# 0            10,000+
# 1           500,000+
# 2         5,000,000+
# 3        50,000,000+
# 4           100,000+
#             ...
# 10836         5,000+
# 10837           100+
# 10838         1,000+
# 10839         1,000+
# 10840    10,000,000+
# Name: Installs, Length: 10840, dtype: object

# %%
data_copy["Installs"].str.replace("+","")
# Out:
# 0            10,000
# 1           500,000
# 2         5,000,000
# 3        50,000,000
# 4           100,000
#             ...
# 10836         5,000
# 10837           100
# 10838         1,000
# 10839         1,000
# 10840    10,000,000
# Name: Installs, Length: 10840, dtype: object

# %%
data_copy["Installs"].str

# %%
data_copy["Installs"].dtype
# Out:
# dtype('O')

# %%
data_copy["Installs"][0]
# Out:
# '10,000+'

# %%
data_copy["Price"].unique()
# Out:
# array(['0', '$4.99', '$3.99', '$6.99', '$1.49', '$2.99', '$7.99', '$5.99',
#        '$3.49', '$1.99', '$9.99', '$7.49', '$0.99', '$9.00', '$5.49',
#        '$10.00', '$24.99', '$11.99', '$79.99', '$16.99', '$14.99',
#        '$1.00', '$29.99', '$12.99', '$2.49', '$10.99', '$1.50', '$19.99',
#        '$15.99', '$33.99', '$74.99', '$39.99', '$3.95', '$4.49', '$1.70',
#        '$8.99', '$2.00', '$3.88', '$25.99', '$399.99', '$17.99',
#        '$400.00', '$3.02', '$1.76', '$4.84', '$4.77', '$1.61', '$2.50',
#        '$1.59', '$6.49', '$1.29', '$5.00', '$13.99', '$299.99', '$379.99',
#        '$37.99', '$18.99', '$389.99', '$19.90', '$8.49', '$1.75',
#        '$14.00', '$4.85', '$46.99', '$109.99', '$154.99', '$3.08',
#        '$2.59', '$4.80', '$1.96', '$19.40', '$3.90', '$4.59', '$15.46',
#        '$3.04', '$4.29', '$2.60', '$3.28', '$4.60', '$28.99', '$2.95',
#        '$2.90', '$1.97', '$200.00', '$89.99', '$2.56', '$30.99', '$3.61',
#        '$394.99', '$1.26', '$1.20', '$1.04'], dtype=object)

# %%
data_copy["Installs"].head(2)
# Out:
# 0     10,000+
# 1    500,000+
# Name: Installs, dtype: object

# %%
data_copy["Installs"]=data_copy["Installs"].str.replace("+","")

# %%
data_copy["Installs"].head(10)
# Out:
# 0        10,000
# 1       500,000
# 2     5,000,000
# 3    50,000,000
# 4       100,000
# 5        50,000
# 6        50,000
# 7     1,000,000
# 8     1,000,000
# 9        10,000
# Name: Installs, dtype: object

# %%
data_copy["Installs"]=data_copy["Installs"].str.replace(",","")

# %%
data_copy["Installs"].head(10)
# Out:
# 0       10000
# 1      500000
# 2     5000000
# 3    50000000
# 4      100000
# 5       50000
# 6       50000
# 7     1000000
# 8     1000000
# 9       10000
# Name: Installs, dtype: object

# %%
data_copy["Price"].unique()
# Out:
# array(['0', '$4.99', '$3.99', '$6.99', '$1.49', '$2.99', '$7.99', '$5.99',
#        '$3.49', '$1.99', '$9.99', '$7.49', '$0.99', '$9.00', '$5.49',
#        '$10.00', '$24.99', '$11.99', '$79.99', '$16.99', '$14.99',
#        '$1.00', '$29.99', '$12.99', '$2.49', '$10.99', '$1.50', '$19.99',
#        '$15.99', '$33.99', '$74.99', '$39.99', '$3.95', '$4.49', '$1.70',
#        '$8.99', '$2.00', '$3.88', '$25.99', '$399.99', '$17.99',
#        '$400.00', '$3.02', '$1.76', '$4.84', '$4.77', '$1.61', '$2.50',
#        '$1.59', '$6.49', '$1.29', '$5.00', '$13.99', '$299.99', '$379.99',
#        '$37.99', '$18.99', '$389.99', '$19.90', '$8.49', '$1.75',
#        '$14.00', '$4.85', '$46.99', '$109.99', '$154.99', '$3.08',
#        '$2.59', '$4.80', '$1.96', '$19.40', '$3.90', '$4.59', '$15.46',
#        '$3.04', '$4.29', '$2.60', '$3.28', '$4.60', '$28.99', '$2.95',
#        '$2.90', '$1.97', '$200.00', '$89.99', '$2.56', '$30.99', '$3.61',
#        '$394.99', '$1.26', '$1.20', '$1.04'], dtype=object)

# %%
data_copy["Price"]=data_copy["Price"].str.replace("$","")

# %%
data_copy["Price"].unique()
# Out:
# array(['0', '4.99', '3.99', '6.99', '1.49', '2.99', '7.99', '5.99',
#        '3.49', '1.99', '9.99', '7.49', '0.99', '9.00', '5.49', '10.00',
#        '24.99', '11.99', '79.99', '16.99', '14.99', '1.00', '29.99',
#        '12.99', '2.49', '10.99', '1.50', '19.99', '15.99', '33.99',
#        '74.99', '39.99', '3.95', '4.49', '1.70', '8.99', '2.00', '3.88',
#        '25.99', '399.99', '17.99', '400.00', '3.02', '1.76', '4.84',
#        '4.77', '1.61', '2.50', '1.59', '6.49', '1.29', '5.00', '13.99',
#        '299.99', '379.99', '37.99', '18.99', '389.99', '19.90', '8.49',
#        '1.75', '14.00', '4.85', '46.99', '109.99', '154.99', '3.08',
#        '2.59', '4.80', '1.96', '19.40', '3.90', '4.59', '15.46', '3.04',
#        '4.29', '2.60', '3.28', '4.60', '28.99', '2.95', '2.90', '1.97',
#        '200.00', '89.99', '2.56', '30.99', '3.61', '394.99', '1.26',
#        '1.20', '1.04'], dtype=object)

# %%
data_copy["Installs"]=data_copy["Installs"].astype("int")

# %%
data_copy["Price"]=data_copy["Price"].astype("float")

# %%
data_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10840 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10840 non-null  object
#  1   Category        10840 non-null  object
#  2   Rating          9366 non-null   float64
#  3   Reviews         10840 non-null  int64
#  4   Size            9145 non-null   float64
#  5   Installs        10840 non-null  int64
#  6   Type            10839 non-null  object
#  7   Price           10840 non-null  float64
#  8   Content Rating  10840 non-null  object
#  9   Genres          10840 non-null  object
#  10  Last Updated    10840 non-null  object
#  11  Current Ver     10832 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1.4+ MB

# %%
data_copy["Last Updated"]
# Out:
# 0         January 7, 2018
# 1        January 15, 2018
# 2          August 1, 2018
# 3            June 8, 2018
# 4           June 20, 2018
#                ...
# 10836       July 25, 2017
# 10837        July 6, 2018
# 10838    January 20, 2017
# 10839    January 19, 2015
# 10840       July 25, 2018
# Name: Last Updated, Length: 10840, dtype: object

# %%
data_copy["Last Updated"].dtype
# Out:
# dtype('O')

# %%
data_copy["Last Updated"]=pd.to_datetime(data_copy["Last Updated"])

# %%
data_copy["Last Updated"]
# Out:
# 0       2018-01-07
# 1       2018-01-15
# 2       2018-08-01
# 3       2018-06-08
# 4       2018-06-20
#            ...
# 10836   2017-07-25
# 10837   2018-07-06
# 10838   2017-01-20
# 10839   2015-01-19
# 10840   2018-07-25
# Name: Last Updated, Length: 10840, dtype: datetime64[ns]

# %%
data_copy["day"]=data_copy["Last Updated"].dt.day

# %%
data_copy["month"]=data_copy["Last Updated"].dt.month

# %%
data_copy["year"]=data_copy["Last Updated"].dt.year

# %%
data_copy.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#    Reviews     Size  Installs  Type  Price Content Rating  \
# 0      159  19000.0     10000  Free    0.0       Everyone
# 1      967  14000.0    500000  Free    0.0       Everyone
# 2    87510   8700.0   5000000  Free    0.0       Everyone
# 3   215644  25000.0  50000000  Free    0.0           Teen
# 4      967   2800.0    100000  Free    0.0       Everyone
#
#                       Genres Last Updated         Current Ver   Android Ver  \
# 0               Art & Design   2018-01-07               1.0.0  4.0.3 and up
# 1  Art & Design;Pretend Play   2018-01-15               2.0.0  4.0.3 and up
# 2               Art & Design   2018-08-01               1.2.4  4.0.3 and up
# 3               Art & Design   2018-06-08  Varies with device    4.2 and up
# 4    Art & Design;Creativity   2018-06-20                 1.1    4.4 and up
#
#    day  month  year
# 0    7      1  2018
# 1   15      1  2018
# 2    1      8  2018
# 3    8      6  2018
# 4   20      6  2018

# %%
data_copy["Android Ver"]
# Out:
# 0              4.0.3 and up
# 1              4.0.3 and up
# 2              4.0.3 and up
# 3                4.2 and up
# 4                4.4 and up
#                 ...
# 10836            4.1 and up
# 10837            4.1 and up
# 10838            2.2 and up
# 10839    Varies with device
# 10840    Varies with device
# Name: Android Ver, Length: 10840, dtype: object

# %%
data_copy["Android Ver"]=data_copy["Android Ver"].str.replace("and up","")

# %%
data_copy["Android Ver"]=data_copy["Android Ver"].str.replace("Varies with device","NaN")

# %%
data_copy.head(2)
# Out:
#                                               App        Category  Rating  \
# 0  Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                             Coloring book moana  ART_AND_DESIGN     3.9
#
#    Reviews     Size  Installs  Type  Price Content Rating  \
# 0      159  19000.0     10000  Free    0.0       Everyone
# 1      967  14000.0    500000  Free    0.0       Everyone
#
#                       Genres Last Updated Current Ver Android Ver  day  month  \
# 0               Art & Design   2018-01-07       1.0.0      4.0.3     7      1
# 1  Art & Design;Pretend Play   2018-01-15       2.0.0      4.0.3    15      1
#
#    year
# 0  2018
# 1  2018

# %%
data_copy.to_csv("clead_google_playstore_data.csv",index=False)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        
warnings.filterwarnings("ignore")

# %matplotlib inline

# %%
# !pip install matplotlib.pyplot
# Out:
# WARNING: Ignoring invalid distribution -yping-extensions (f:\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -yping-extensions (f:\anaconda\lib\site-packages)
# ERROR: Could not find a version that satisfies the requirement matplotlib.pyplot (from versions: none)
# ERROR: No matching distribution found for matplotlib.pyplot
# WARNING: Ignoring invalid distribution -yping-extensions (f:\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -yping-extensions (f:\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -yping-extensions (f:\anaconda\lib\site-packages)

# %%
import matplotlib.pyplot as plt

# %%
# !pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in f:\anaconda\lib\site-packages (3.5.1)
# Requirement already satisfied: python-dateutil>=2.7 in f:\anaconda\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: pillow>=6.2.0 in f:\anaconda\lib\site-packages (from matplotlib) (9.0.1)
# Requirement already satisfied: cycler>=0.10 in f:\anaconda\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: packaging>=20.0 in f:\anaconda\lib\site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pyparsing>=2.2.1 in f:\anaconda\lib\site-packages (from matplotlib) (3.0.4)
# Requirement already satisfied: numpy>=1.17 in f:\anaconda\lib\site-packages (from matplotlib) (2.0.2)
# Requirement already satisfied: fonttools>=4.22.0 in f:\anaconda\lib\site-packages (from matplotlib) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in f:\anaconda\lib\site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: six>=1.5 in f:\anaconda\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# WARNING: Ignoring invalid distribution -yping-extensions (f:\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -yping-extensions (f:\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -yping-extensions (f:\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -yping-extensions (f:\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -yping-extensions (f:\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -yping-extensions (f:\anaconda\lib\site-packages)

# %%
import sys
# !{sys.executable} -m pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in f:\anaconda\envs\dev_env\lib\site-packages (3.10.8)
# Requirement already satisfied: contourpy>=1.0.1 in f:\anaconda\envs\dev_env\lib\site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in f:\anaconda\envs\dev_env\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in f:\anaconda\envs\dev_env\lib\site-packages (from matplotlib) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in f:\anaconda\envs\dev_env\lib\site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: numpy>=1.23 in f:\anaconda\envs\dev_env\lib\site-packages (from matplotlib) (2.2.5)
# Requirement already satisfied: packaging>=20.0 in f:\anaconda\envs\dev_env\lib\site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in f:\anaconda\envs\dev_env\lib\site-packages (from matplotlib) (12.1.1)
# Requirement already satisfied: pyparsing>=3 in f:\anaconda\envs\dev_env\lib\site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in f:\anaconda\envs\dev_env\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in f:\anaconda\envs\dev_env\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)

# %%
import matplotlib.pyplot as plt

# %%
import sys
# !{sys.executable} -m pip install seaborn
# Out:
# Requirement already satisfied: seaborn in f:\anaconda\envs\dev_env\lib\site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in f:\anaconda\envs\dev_env\lib\site-packages (from seaborn) (2.2.5)
# Requirement already satisfied: pandas>=1.2 in f:\anaconda\envs\dev_env\lib\site-packages (from seaborn) (2.3.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in f:\anaconda\envs\dev_env\lib\site-packages (from seaborn) (3.10.8)
# Requirement already satisfied: contourpy>=1.0.1 in f:\anaconda\envs\dev_env\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in f:\anaconda\envs\dev_env\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in f:\anaconda\envs\dev_env\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in f:\anaconda\envs\dev_env\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in f:\anaconda\envs\dev_env\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (25.0)
# Requirement already satisfied: pillow>=8 in f:\anaconda\envs\dev_env\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (12.1.1)
# Requirement already satisfied: pyparsing>=3 in f:\anaconda\envs\dev_env\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in f:\anaconda\envs\dev_env\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in f:\anaconda\envs\dev_env\lib\site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in f:\anaconda\envs\dev_env\lib\site-packages (from pandas>=1.2->seaborn) (2025.3)
# Requirement already satisfied: six>=1.5 in f:\anaconda\envs\dev_env\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)

# %%
df=pd.read_csv("clead_google_playstore_data.csv")

# %%
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#    Reviews     Size  Installs  Type  Price Content Rating  \
# 0      159  19000.0     10000  Free    0.0       Everyone
# 1      967  14000.0    500000  Free    0.0       Everyone
# 2    87510   8700.0   5000000  Free    0.0       Everyone
# 3   215644  25000.0  50000000  Free    0.0           Teen
# 4      967   2800.0    100000  Free    0.0       Everyone
#
#                       Genres Last Updated         Current Ver Android Ver  \
# 0               Art & Design   2018-01-07               1.0.0      4.0.3
# 1  Art & Design;Pretend Play   2018-01-15               2.0.0      4.0.3
# 2               Art & Design   2018-08-01               1.2.4      4.0.3
# 3               Art & Design   2018-06-08  Varies with device        4.2
# 4    Art & Design;Creativity   2018-06-20                 1.1        4.4
#
#    day  month  year
# 0    7      1  2018
# 1   15      1  2018
# 2    1      8  2018
# 3    8      6  2018
# 4   20      6  2018

# %%
df.tail()
# Out:
#                                                  App             Category  \
# 10835                               Sya9a Maroc - FR               FAMILY
# 10836               Fr. Mike Schmitz Audio Teachings               FAMILY
# 10837                         Parkinson Exercices FR              MEDICAL
# 10838                  The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10839  iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        Rating  Reviews     Size  Installs  Type  Price Content Rating  \
# 10835     4.5       38  53000.0      5000  Free    0.0       Everyone
# 10836     5.0        4   3600.0       100  Free    0.0       Everyone
# 10837     NaN        3   9500.0      1000  Free    0.0       Everyone
# 10838     4.5      114      NaN      1000  Free    0.0     Mature 17+
# 10839     4.5   398307  19000.0  10000000  Free    0.0       Everyone
#
#                   Genres Last Updated         Current Ver Android Ver  day  \
# 10835          Education   2017-07-25                1.48        4.1    25
# 10836          Education   2018-07-06                 1.0        4.1     6
# 10837            Medical   2017-01-20                 1.0        2.2    20
# 10838  Books & Reference   2015-01-19  Varies with device         NaN   19
# 10839          Lifestyle   2018-07-25  Varies with device         NaN   25
#
#        month  year
# 10835      7  2017
# 10836      7  2018
# 10837      1  2017
# 10838      1  2015
# 10839      7  2018

# %%
df.sample(10)
# Out:
#                                   App          Category  Rating  Reviews  \
# 973                            Redbox     ENTERTAINMENT     4.1   115033
# 6254                    ZiraatBank BH           FINANCE     4.1       58
# 1087            Alfa-Bank (Alfa-Bank)           FINANCE     4.0    44545
# 2836                     ASUS Gallery       PHOTOGRAPHY     4.3   125259
# 8969               DV Web Design Tips      PRODUCTIVITY     NaN        1
# 4388                        Tap N Pay      PRODUCTIVITY     4.4      253
# 8225   ReDNAKET DB Normalization Tool             TOOLS     NaN        0
# 9552                          El Falı            FAMILY     4.8    36968
# 9337         EG | Explore Folegandros  TRAVEL_AND_LOCAL     NaN        0
# 10675                   Calculator Fn             TOOLS     NaN        9
#
#           Size  Installs  Type  Price Content Rating          Genres  \
# 973    30000.0  10000000  Free   0.00       Everyone   Entertainment
# 6254    3500.0     10000  Free   0.00       Everyone         Finance
# 1087       NaN   1000000  Free   0.00       Everyone         Finance
# 2836       NaN  50000000  Free   0.00       Everyone     Photography
# 8969    5100.0        10  Free   0.00           Teen    Productivity
# 4388    8200.0     10000  Free   0.00       Everyone    Productivity
# 8225     940.0        10  Paid   0.99       Everyone           Tools
# 9552   16000.0   1000000  Free   0.00       Everyone   Entertainment
# 9337   56000.0         0  Paid   3.99       Everyone  Travel & Local
# 10675   3600.0       500  Free   0.00       Everyone           Tools
#
#       Last Updated         Current Ver Android Ver  day  month  year
# 973     2018-07-02               7.5.0        5.0     2      7  2018
# 6254    2017-07-04               2.3.2        4.0     4      7  2017
# 1087    2018-07-31  Varies with device         NaN   31      7  2018
# 2836    2018-08-02  Varies with device         NaN    2      8  2018
# 8969    2017-10-26               1.0.0        4.1    26     10  2017
# 4388    2018-07-31              0.1.22        4.1    31      7  2018
# 8225    2016-02-03               1.0.2        5.0     3      2  2016
# 9552    2017-11-03               1.2.9        2.3     3     11  2017
# 9337    2017-01-22               1.1.1        4.1    22      1  2017
# 10675   2015-11-12                 1.4        4.0    12     11  2015

# %%
df.shape
# Out:
# (10840, 16)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10840 entries, 0 to 10839
# Data columns (total 16 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10840 non-null  object
#  1   Category        10840 non-null  object
#  2   Rating          9366 non-null   float64
#  3   Reviews         10840 non-null  int64
#  4   Size            9145 non-null   float64
#  5   Installs        10840 non-null  int64
#  6   Type            10839 non-null  object
#  7   Price           10840 non-null  float64
#  8   Content Rating  10840 non-null  object
#  9   Genres          10840 non-null  object
#  10  Last Updated    10840 non-null  object
#  11  Current Ver     10832 non-null  object
#  12  Android Ver     9476 non-null   object
#  13  day             10840 non-null  int64
#  14  month           10840 non-null  int64
#  15  year            10840 non-null  int64
# dtypes: float64(3), int64(5), object(8)
# memory usage: 1.3+ MB

# %%
df.describe().T
# Out:
#             count          mean           std     min     25%       50%  \
# Rating     9366.0  4.191757e+00  5.152189e-01     1.0     4.0       4.3
# Reviews   10840.0  4.441529e+05  2.927761e+06     0.0    38.0    2094.0
# Size       9145.0  2.150653e+04  2.259602e+04    10.0  4900.0   13000.0
# Installs  10840.0  1.546434e+07  8.502936e+07     0.0  1000.0  100000.0
# Price     10840.0  1.027368e+00  1.594970e+01     0.0     0.0       0.0
# day       10840.0  1.560904e+01  9.561621e+00     1.0     6.0      16.0
# month     10840.0  6.422325e+00  2.578388e+00     1.0     5.0       7.0
# year      10840.0  2.017400e+03  1.100914e+00  2010.0  2017.0    2018.0
#
#                 75%           max
# Rating          4.5  5.000000e+00
# Reviews     54775.5  7.815831e+07
# Size        30000.0  1.000000e+05
# Installs  5000000.0  1.000000e+09
# Price           0.0  4.000000e+02
# day            24.0  3.100000e+01
# month           8.0  1.200000e+01
# year         2018.0  2.018000e+03

# %%
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#    Reviews     Size  Installs  Type  Price Content Rating  \
# 0      159  19000.0     10000  Free    0.0       Everyone
# 1      967  14000.0    500000  Free    0.0       Everyone
# 2    87510   8700.0   5000000  Free    0.0       Everyone
# 3   215644  25000.0  50000000  Free    0.0           Teen
# 4      967   2800.0    100000  Free    0.0       Everyone
#
#                       Genres Last Updated         Current Ver Android Ver  \
# 0               Art & Design   2018-01-07               1.0.0      4.0.3
# 1  Art & Design;Pretend Play   2018-01-15               2.0.0      4.0.3
# 2               Art & Design   2018-08-01               1.2.4      4.0.3
# 3               Art & Design   2018-06-08  Varies with device        4.2
# 4    Art & Design;Creativity   2018-06-20                 1.1        4.4
#
#    day  month  year
# 0    7      1  2018
# 1   15      1  2018
# 2    1      8  2018
# 3    8      6  2018
# 4   20      6  2018

# %%
df.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver', 'day', 'month', 'year'],
#       dtype='object')

# %%
df[df.duplicated()]
# Out:
#                                                    App      Category  Rating  \
# 229                       Quick PDF Scanner + OCR FREE      BUSINESS     4.2
# 236                                                Box      BUSINESS     4.2
# 239                                 Google My Business      BUSINESS     4.4
# 256                                ZOOM Cloud Meetings      BUSINESS     4.4
# 261                          join.me - Simple Meetings      BUSINESS     4.0
# ...                                                ...           ...     ...
# 8643                    Wunderlist: To-Do List & Tasks  PRODUCTIVITY     4.6
# 8654   TickTick: To Do List with Reminder, Day Planner  PRODUCTIVITY     4.6
# 8658                           ColorNote Notepad Notes  PRODUCTIVITY     4.6
# 10049        Airway Ex - Intubate. Anesthetize. Train.       MEDICAL     4.3
# 10767                                             AAFP       MEDICAL     3.8
#
#        Reviews     Size   Installs  Type  Price Content Rating        Genres  \
# 229      80805      NaN    5000000  Free    0.0       Everyone      Business
# 236     159872      NaN   10000000  Free    0.0       Everyone      Business
# 239      70991      NaN    5000000  Free    0.0       Everyone      Business
# 256      31614  37000.0   10000000  Free    0.0       Everyone      Business
# 261       6989      NaN    1000000  Free    0.0       Everyone      Business
# ...        ...      ...        ...   ...    ...            ...           ...
# 8643    404610      NaN   10000000  Free    0.0       Everyone  Productivity
# 8654     25370      NaN    1000000  Free    0.0       Everyone  Productivity
# 8658   2401017      NaN  100000000  Free    0.0       Everyone  Productivity
# 10049      123  86000.0      10000  Free    0.0       Everyone       Medical
# 10767       63  24000.0      10000  Free    0.0       Everyone       Medical
#
#       Last Updated         Current Ver Android Ver  day  month  year
# 229     2018-02-26  Varies with device      4.0.3    26      2  2018
# 236     2018-07-31  Varies with device         NaN   31      7  2018
# 239     2018-07-24    2.19.0.204537701        4.4    24      7  2018
# 256     2018-07-20      4.1.28165.0716        4.0    20      7  2018
# 261     2018-07-16           4.3.0.508        4.4    16      7  2018
# ...            ...                 ...         ...  ...    ...   ...
# 8643    2018-04-06  Varies with device         NaN    6      4  2018
# 8654    2018-08-06  Varies with device         NaN    6      8  2018
# 8658    2018-06-27  Varies with device         NaN   27      6  2018
# 10049   2018-06-01              0.6.88        5.0     1      6  2018
# 10767   2018-06-22               2.3.1        5.0    22      6  2018
#
# [483 rows x 16 columns]

# %%
df[df.duplicated('Reviews')]
# Out:
#                                           App             Category  Rating  \
# 4       Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN     4.3
# 57                 Extreme Rally Championship    AUTO_AND_VEHICLES     4.2
# 126              Skin Care and Natural Beauty               BEAUTY     NaN
# 134             Lady adviser (beauty, health)               BEAUTY     NaN
# 156    Offline: English to Tagalog Dictionary  BOOKS_AND_REFERENCE     4.7
# ...                                       ...                  ...     ...
# 10834                                FR Forms             BUSINESS     NaN
# 10835                        Sya9a Maroc - FR               FAMILY     4.5
# 10836        Fr. Mike Schmitz Audio Teachings               FAMILY     5.0
# 10837                  Parkinson Exercices FR              MEDICAL     NaN
# 10838           The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE     4.5
#
#        Reviews     Size  Installs  Type  Price Content Rating  \
# 4          967   2800.0    100000  Free    0.0       Everyone
# 57         129  54000.0    100000  Free    0.0       Everyone
# 126        654   7400.0    100000  Free    0.0           Teen
# 134         30   9900.0     10000  Free    0.0     Mature 17+
# 156        967   6700.0    500000  Free    0.0       Everyone
# ...        ...      ...       ...   ...    ...            ...
# 10834        0   9600.0        10  Free    0.0       Everyone
# 10835       38  53000.0      5000  Free    0.0       Everyone
# 10836        4   3600.0       100  Free    0.0       Everyone
# 10837        3   9500.0      1000  Free    0.0       Everyone
# 10838      114      NaN      1000  Free    0.0     Mature 17+
#
#                         Genres Last Updated         Current Ver Android Ver  \
# 4      Art & Design;Creativity   2018-06-20                 1.1        4.4
# 57             Auto & Vehicles   2018-07-26                 3.0        4.1
# 126                     Beauty   2018-07-17                1.15        4.1
# 134                     Beauty   2018-01-24                 3.0        3.0
# 156          Books & Reference   2018-08-04               1.1.6      4.0.3
# ...                        ...          ...                 ...         ...
# 10834                 Business   2016-09-29               1.1.5        4.0
# 10835                Education   2017-07-25                1.48        4.1
# 10836                Education   2018-07-06                 1.0        4.1
# 10837                  Medical   2017-01-20                 1.0        2.2
# 10838        Books & Reference   2015-01-19  Varies with device         NaN
#
#        day  month  year
# 4       20      6  2018
# 57      26      7  2018
# 126     17      7  2018
# 134     24      1  2018
# 156      4      8  2018
# ...    ...    ...   ...
# 10834   29      9  2016
# 10835   25      7  2017
# 10836    6      7  2018
# 10837   20      1  2017
# 10838   19      1  2015
#
# [4839 rows x 16 columns]

# %%
df.shape
# Out:
# (10840, 16)

# %%
df=df.drop_duplicates(subset=['App'],keep='first')

# %%
df['App'].duplicated().sum()
# Out:
# np.int64(0)

# %%
df.shape
# Out:
# (9659, 16)

# %%
dups = df[df['App'].duplicated(keep=False)]

# %%
dups
# Out:
# Empty DataFrame
# Columns: [App, Category, Rating, Reviews, Size, Installs, Type, Price, Content Rating, Genres, Last Updated, Current Ver, Android Ver, day, month, year]
# Index: []

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9659 entries, 0 to 10839
# Data columns (total 16 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             9659 non-null   object
#  1   Category        9659 non-null   object
#  2   Rating          8196 non-null   float64
#  3   Reviews         9659 non-null   int64
#  4   Size            8432 non-null   float64
#  5   Installs        9659 non-null   int64
#  6   Type            9658 non-null   object
#  7   Price           9659 non-null   float64
#  8   Content Rating  9659 non-null   object
#  9   Genres          9659 non-null   object
#  10  Last Updated    9659 non-null   object
#  11  Current Ver     9651 non-null   object
#  12  Android Ver     8667 non-null   object
#  13  day             9659 non-null   int64
#  14  month           9659 non-null   int64
#  15  year            9659 non-null   int64
# dtypes: float64(3), int64(5), object(8)
# memory usage: 1.3+ MB

# %%
numeric_features = [feature for feature in df.columns if df[feature].dtype != 'O']

# %%
numeric_features
# Out:
# ['Rating', 'Reviews', 'Size', 'Installs', 'Price', 'day', 'month', 'year']

# %%
df[numeric_features]
# Out:
#        Rating  Reviews     Size  Installs  Price  day  month  year
# 0         4.1      159  19000.0     10000    0.0    7      1  2018
# 1         3.9      967  14000.0    500000    0.0   15      1  2018
# 2         4.7    87510   8700.0   5000000    0.0    1      8  2018
# 3         4.5   215644  25000.0  50000000    0.0    8      6  2018
# 4         4.3      967   2800.0    100000    0.0   20      6  2018
# ...       ...      ...      ...       ...    ...  ...    ...   ...
# 10835     4.5       38  53000.0      5000    0.0   25      7  2017
# 10836     5.0        4   3600.0       100    0.0    6      7  2018
# 10837     NaN        3   9500.0      1000    0.0   20      1  2017
# 10838     4.5      114      NaN      1000    0.0   19      1  2015
# 10839     4.5   398307  19000.0  10000000    0.0   25      7  2018
#
# [9659 rows x 8 columns]

# %%
categorical_features = [feature for feature in df.columns if df[feature].dtype == 'O']

# %%
categorical_features
# Out:
# ['App',
#  'Category',
#  'Type',
#  'Content Rating',
#  'Genres',
#  'Last Updated',
#  'Current Ver',
#  'Android Ver']

# %%
df[categorical_features]
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10835                                   Sya9a Maroc - FR               FAMILY
# 10836                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10837                             Parkinson Exercices FR              MEDICAL
# 10838                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10839      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        Type Content Rating                     Genres Last Updated  \
# 0      Free       Everyone               Art & Design   2018-01-07
# 1      Free       Everyone  Art & Design;Pretend Play   2018-01-15
# 2      Free       Everyone               Art & Design   2018-08-01
# 3      Free           Teen               Art & Design   2018-06-08
# 4      Free       Everyone    Art & Design;Creativity   2018-06-20
# ...     ...            ...                        ...          ...
# 10835  Free       Everyone                  Education   2017-07-25
# 10836  Free       Everyone                  Education   2018-07-06
# 10837  Free       Everyone                    Medical   2017-01-20
# 10838  Free     Mature 17+          Books & Reference   2015-01-19
# 10839  Free       Everyone                  Lifestyle   2018-07-25
#
#               Current Ver Android Ver
# 0                   1.0.0      4.0.3
# 1                   2.0.0      4.0.3
# 2                   1.2.4      4.0.3
# 3      Varies with device        4.2
# 4                     1.1        4.4
# ...                   ...         ...
# 10835                1.48        4.1
# 10836                 1.0        4.1
# 10837                 1.0        2.2
# 10838  Varies with device         NaN
# 10839  Varies with device         NaN
#
# [9659 rows x 8 columns]

# %%
categorical_features
# Out:
# ['App',
#  'Category',
#  'Type',
#  'Content Rating',
#  'Genres',
#  'Last Updated',
#  'Current Ver',
#  'Android Ver']

# %%
df['Type'].value_counts()
# Out:
# Type
# Free    8902
# Paid     756
# Name: count, dtype: int64

# %%
df['Type'].value_counts(normalize=True)
# Out:
# Type
# Free    0.921723
# Paid    0.078277
# Name: proportion, dtype: float64

# %%
for col in categorical_features:
    print(col)
# Out:
# App
# Category
# Type
# Content Rating
# Genres
# Last Updated
# Current Ver
# Android Ver

# %%
for col in categorical_features:
    print(f"{col}:{df[col].value_counts(normalize=True)*100}")
    print("=============================================")
# Out:
# App:App
# iHoroscope - 2018 Daily Horoscope & Astrology         0.010353
# Photo Editor & Candy Camera & Grid & ScrapBook        0.010353
# Coloring book moana                                   0.010353
# U Launcher Lite – FREE Live Cool Themes, Hide Apps    0.010353
# Sketch - Draw & Paint                                 0.010353
#                                                         ...
# Learn To Draw Kawaii Characters                       0.010353
# 3D Color Pixel by Number - Sandbox Art Coloring       0.010353
# Mandala Coloring Book                                 0.010353
# Tattoo Name On My Photo Editor                        0.010353
# Name Art Photo Editor - Focus n Filters               0.010353
# Name: proportion, Length: 9659, dtype: float64
# =============================================
# Category:Category
# FAMILY                 18.966767
# GAME                    9.928564
# TOOLS                   8.561963
# BUSINESS                4.348276
# MEDICAL                 4.089450
# PERSONALIZATION         3.892743
# PRODUCTIVITY            3.872036
# LIFESTYLE               3.820271
# FINANCE                 3.571798
# SPORTS                  3.364738
# COMMUNICATION           3.261207
# HEALTH_AND_FITNESS      2.981675
# PHOTOGRAPHY             2.909204
# NEWS_AND_MAGAZINES      2.629672
# SOCIAL                  2.474376
# BOOKS_AND_REFERENCE     2.298375
# TRAVEL_AND_LOCAL        2.267315
# SHOPPING                2.091314
# DATING                  1.770370
# VIDEO_PLAYERS           1.687545
# MAPS_AND_NAVIGATION     1.356248
# EDUCATION               1.232012
# FOOD_AND_DRINK          1.159540
# ENTERTAINMENT           1.056010
# AUTO_AND_VEHICLES       0.880008
# LIBRARIES_AND_DEMO      0.869655
# WEATHER                 0.817890
# HOUSE_AND_HOME          0.766125
# ART_AND_DESIGN          0.662594
# EVENTS                  0.662594
# PARENTING               0.621182
# COMICS                  0.579770
# BEAUTY                  0.548711
# Name: proportion, dtype: float64
# =============================================
# Type:Type
# Free    92.172292
# Paid     7.827708
# Name: proportion, dtype: float64
# =============================================
# Content Rating:Content Rating
# Everyone           81.820064
# Teen               10.725748
# Mature 17+          4.068744
# Everyone 10+        3.333678
# Adults only 18+     0.031059
# Unrated             0.020706
# Name: proportion, dtype: float64
# =============================================
# Genres:Genres
# Tools                       8.551610
# Entertainment               5.808055
# Education                   5.280050
# Business                    4.348276
# Medical                     4.089450
#                               ...
# Role Playing;Brain Games    0.010353
# Strategy;Education          0.010353
# Racing;Pretend Play         0.010353
# Communication;Creativity    0.010353
# Strategy;Creativity         0.010353
# Name: proportion, Length: 118, dtype: float64
# =============================================
# Last Updated:Last Updated
# 2018-08-03    2.608966
# 2018-08-02    2.381199
# 2018-08-01    2.163785
# 2018-07-31    2.112020
# 2018-07-30    1.656486
#                 ...
# 2011-03-16    0.010353
# 2014-03-09    0.010353
# 2016-05-05    0.010353
# 2014-02-16    0.010353
# 2014-01-20    0.010353
# Name: proportion, Length: 1377, dtype: float64
# =============================================
# Current Ver:Current Ver
# Varies with device    10.931510
# 1.0                    8.278935
# 1.1                    2.694021
# 1.2                    1.823645
# 2.0                    1.543881
#                         ...
# 0.7.1                  0.010362
# 4.6.71                 0.010362
# 2.0.148.0              0.010362
# 1.0.0.96               0.010362
# 1.022                  0.010362
# Name: proportion, Length: 2817, dtype: float64
# =============================================
# Android Ver:Android Ver
# 4.1              25.406715
# 4.0.3            16.095535
# 4.0              14.826353
# 4.4               9.438099
# 2.3               7.107419
# 5.0               5.907465
# 4.2               4.292143
# 2.3.3             3.149879
# 2.2               2.757586
# 3.0               2.665282
# 4.3               2.549902
# 2.1               1.534556
# 1.6               1.338410
# 6.0               0.623053
# 7.0               0.484597
# 3.2               0.415369
# 2.0               0.369217
# 5.1               0.253836
# 1.5               0.230760
# 4.4W              0.126918
# 3.1               0.115380
# 2.0.1             0.080766
# 8.0               0.069228
# 7.1               0.034614
# 5.0 - 8.0         0.023076
# 4.0.3 - 7.1.1     0.023076
# 1.0               0.023076
# 7.0 - 7.1.1       0.011538
# 4.1 - 7.1.1       0.011538
# 5.0 - 6.0         0.011538
# 2.2 - 7.1.1       0.011538
# 5.0 - 7.1.1       0.011538
# Name: proportion, dtype: float64
# =============================================

# %%
sns.set_style("darkgrid")

# %%
plt.figure(figsize=(10, 6))
sns.countplot(x="Type", data=df)
# Out:
# <Axes: xlabel='Type', ylabel='count'>

# %%
sns.countplot(x="Type", data=df, palette="magma")
plt.title("Distribution of App Types", fontsize=16, weight="bold")
plt.xlabel("App Type",fontsize=16, weight="bold")
plt.ylabel("Count",fontsize=16, weight="bold")
# Out:
# Text(0, 0.5, 'Count')

# %%
sns.countplot(x="Content Rating", data=df, palette="viridis")
plt.title("content Rating", fontsize=16, weight="bold")
plt.xlabel("content",fontsize=16, weight="bold")
plt.xticks(rotation=45)

plt.ylabel("Count",fontsize=16, weight="bold")
# Out:
# Text(0, 0.5, 'Count')

# %%
# categorical columns
plt.figure(figsize=(20, 15))
plt.suptitle('Univariate Analysis of Categorical Features', fontsize=20, fontweight='bold', alpha=0.8, y=1.)
category = [ 'Type', 'Content Rating']
for i in range(0, len(category)):
    plt.subplot(2, 2, i+1)
    sns.countplot(x=df[category[i]],palette="Set2")
    plt.xlabel(category[i])
    plt.xticks(rotation=45)
    plt.tight_layout()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9659 entries, 0 to 10839
# Data columns (total 16 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             9659 non-null   object
#  1   Category        9659 non-null   object
#  2   Rating          8196 non-null   float64
#  3   Reviews         9659 non-null   int64
#  4   Size            8432 non-null   float64
#  5   Installs        9659 non-null   int64
#  6   Type            9658 non-null   object
#  7   Price           9659 non-null   float64
#  8   Content Rating  9659 non-null   object
#  9   Genres          9659 non-null   object
#  10  Last Updated    9659 non-null   object
#  11  Current Ver     9651 non-null   object
#  12  Android Ver     8667 non-null   object
#  13  day             9659 non-null   int64
#  14  month           9659 non-null   int64
#  15  year            9659 non-null   int64
# dtypes: float64(3), int64(5), object(8)
# memory usage: 1.3+ MB

# %%
df['Content Rating'].sample(20)
# Out:
# 6479         Everyone
# 1685     Everyone 10+
# 7491       Mature 17+
# 6816         Everyone
# 5008         Everyone
# 7313             Teen
# 9785         Everyone
# 611        Mature 17+
# 7358     Everyone 10+
# 10260        Everyone
# 3748             Teen
# 3958       Mature 17+
# 4770         Everyone
# 5377         Everyone
# 5698             Teen
# 5851         Everyone
# 3125         Everyone
# 2013         Everyone
# 6939         Everyone
# 5743         Everyone
# Name: Content Rating, dtype: object

# %%
numeric_features
# Out:
# ['Rating', 'Reviews', 'Size', 'Installs', 'Price', 'day', 'month', 'year']

# %%
sns.kdeplot(df['Price'])
# Out:
# <Axes: xlabel='Price', ylabel='Density'>

# %%
sns.distplot(df['Price'])
# Out:
# <Axes: xlabel='Price', ylabel='Density'>

# %%
sns.distplot(df['Reviews'])
# Out:
# <Axes: xlabel='Reviews', ylabel='Density'>

# %%
sns.distplot(df['Rating'])
# Out:
# <Axes: xlabel='Rating', ylabel='Density'>

# %%
sns.kdeplot(df["Rating"])
# Out:
# <Axes: xlabel='Rating', ylabel='Density'>

# %%
plt.figure(figsize=(15, 15))
plt.suptitle('Univariate Analysis of Numerical Features', fontsize=20, fontweight='bold', alpha=0.8, y=1.)

for i in range(0, len(numeric_features)):
    plt.subplot(5, 3, i+1)
    sns.kdeplot(x=df[numeric_features[i]],shade=True, color='r')
    plt.xlabel(numeric_features[i])
    plt.tight_layout()

# %%
numeric_features
# Out:
# ['Rating', 'Reviews', 'Size', 'Installs', 'Price', 'day', 'month', 'year']

# %%
df[df['Category'] == 'SPORTS']
# Out:
#                                  App Category  Rating  Reviews     Size  \
# 2959                            ESPN   SPORTS     4.2   521138      NaN
# 2960                  Free Sports TV   SPORTS     4.3     1802   9800.0
# 2961   LiveScore: Live Sport Updates   SPORTS     4.4   283662      NaN
# 2962                      MLB At Bat   SPORTS     4.2    82882      NaN
# 2963                             NFL   SPORTS     4.1   459795      NaN
# ...                              ...      ...     ...      ...      ...
# 10603          Florida State Gameday   SPORTS     4.7     1566  26000.0
# 10644   Football Manager Mobile 2018   SPORTS     3.9    11460      NaN
# 10682              Hunting Safari 3D   SPORTS     4.2    36183  20000.0
# 10722                    Mobile Kick   SPORTS     4.3   111809  40000.0
# 10774             FQ - Football Quiz   SPORTS     NaN        1   9000.0
#
#        Installs  Type  Price Content Rating  Genres Last Updated  \
# 2959   10000000  Free   0.00   Everyone 10+  Sports   2018-07-19
# 2960     100000  Free   0.00       Everyone  Sports   2018-06-21
# 2961   10000000  Free   0.00       Everyone  Sports   2018-06-15
# 2962    5000000  Free   0.00       Everyone  Sports   2018-07-30
# 2963   50000000  Free   0.00       Everyone  Sports   2018-08-02
# ...         ...   ...    ...            ...     ...          ...
# 10603     50000  Free   0.00       Everyone  Sports   2018-07-13
# 10644    100000  Paid   8.99       Everyone  Sports   2018-06-27
# 10682   5000000  Free   0.00           Teen  Sports   2018-01-20
# 10722  10000000  Free   0.00       Everyone  Sports   2018-02-07
# 10774         1  Free   0.00       Everyone  Sports   2018-05-29
#
#               Current Ver Android Ver  day  month  year
# 2959   Varies with device        5.0    19      7  2018
# 2960                  1.4      4.0.3    21      6  2018
# 2961   Varies with device        4.1    15      6  2018
# 2962   Varies with device         NaN   30      7  2018
# 2963   Varies with device         NaN    2      8  2018
# ...                   ...         ...  ...    ...   ...
# 10603              9.19.2        4.1    13      7  2018
# 10644  Varies with device        4.1    27      6  2018
# 10682                 1.4        2.1    20      1  2018
# 10722              1.0.21        4.1     7      2  2018
# 10774                 1.0        5.0    29      5  2018
#
# [325 rows x 16 columns]

# %%
df["Category"].value_counts()
# Out:
# Category
# FAMILY                 1832
# GAME                    959
# TOOLS                   827
# BUSINESS                420
# MEDICAL                 395
# PERSONALIZATION         376
# PRODUCTIVITY            374
# LIFESTYLE               369
# FINANCE                 345
# SPORTS                  325
# COMMUNICATION           315
# HEALTH_AND_FITNESS      288
# PHOTOGRAPHY             281
# NEWS_AND_MAGAZINES      254
# SOCIAL                  239
# BOOKS_AND_REFERENCE     222
# TRAVEL_AND_LOCAL        219
# SHOPPING                202
# DATING                  171
# VIDEO_PLAYERS           163
# MAPS_AND_NAVIGATION     131
# EDUCATION               119
# FOOD_AND_DRINK          112
# ENTERTAINMENT           102
# AUTO_AND_VEHICLES        85
# LIBRARIES_AND_DEMO       84
# WEATHER                  79
# HOUSE_AND_HOME           74
# ART_AND_DESIGN           64
# EVENTS                   64
# PARENTING                60
# COMICS                   56
# BEAUTY                   53
# Name: count, dtype: int64

# %%
df["Category"].value_counts().plot.pie(figsize=(15,15),autopct='%1.1f%%')
# Out:
# <Axes: ylabel='count'>

# %%
df_cat=df["Category"].value_counts()[:10]

# %%
category = pd.DataFrame(df['Category'].value_counts())        #Dataframe of apps on the basis of category
category.rename(columns = {'Category':'Count'},inplace=True)

# %%
category
# Out:
#                      count
# Category
# FAMILY                1832
# GAME                   959
# TOOLS                  827
# BUSINESS               420
# MEDICAL                395
# PERSONALIZATION        376
# PRODUCTIVITY           374
# LIFESTYLE              369
# FINANCE                345
# SPORTS                 325
# COMMUNICATION          315
# HEALTH_AND_FITNESS     288
# PHOTOGRAPHY            281
# NEWS_AND_MAGAZINES     254
# SOCIAL                 239
# BOOKS_AND_REFERENCE    222
# TRAVEL_AND_LOCAL       219
# SHOPPING               202
# DATING                 171
# VIDEO_PLAYERS          163
# MAPS_AND_NAVIGATION    131
# EDUCATION              119
# FOOD_AND_DRINK         112
# ENTERTAINMENT          102
# AUTO_AND_VEHICLES       85
# LIBRARIES_AND_DEMO      84
# WEATHER                 79
# HOUSE_AND_HOME          74
# ART_AND_DESIGN          64
# EVENTS                  64
# PARENTING               60
# COMICS                  56
# BEAUTY                  53

# %%
plt.figure(figsize=(15,6))
sns.barplot(x=df_cat,y=category['count'],data = category[:10],palette='hls')
plt.title('Top 10 App categories')
plt.xticks(rotation=90)
plt.show()
